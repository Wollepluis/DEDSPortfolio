# %% [markdown]
# # SETUP

# %% [markdown]
# #### Imports

# %%
import warnings
warnings.simplefilter('ignore')
import pandas
import sqlite3

# %% [markdown]
# #### Inlezen van de data

# %%
conn = sqlite3.connect("../Data/HulpmiddelenBS/go_sales_train.sqlite")

tables_query = "SELECT name FROM sqlite_master WHERE type= 'table';"
tables = pandas.read_sql(tables_query, conn)
